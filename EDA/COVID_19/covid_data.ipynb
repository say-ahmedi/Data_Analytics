# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# path = '../datasets_to_an/Titanic-Dataset.csv'
path = '../../datasets_to_an/Titanic-Dataset.csv'
# 1. Load and Inspect the Data
# TODO: Load the CSV file into a DataFrame using `pd.read_csv()`.
# TODO: Check the first few rows using `.head()` to understand the structure.
# TODO: Use `.info()` to get an overview of the dataset (columns, data types, non-null counts).
# TODO: Use `.describe()` to get summary statistics for numerical columns.
# TODO: Check for the shape of the dataset using `.shape`.
data = pd.read_csv(path)
df = pd.DataFrame(data)
# data.head(5)
df.describe()

# df.isnull().sum()
df.head(5)
# df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum()
# 2. Handle Missing Data
# TODO: Identify missing values using `.isnull().sum()`.
# TODO: Decide how to handle missing values: drop them (`dropna()`), fill them (`fillna()`), or impute them (e.g., mean/median for numerical columns, mode for categorical columns).
# df['Age'].fillna(0,inplace=True,axis=0)
# Out:
# 0

# %%
# 3. Explore Categorical Data
# TODO: Use `.value_counts()` to explore the distribution of categorical columns (e.g., `Sex`, `Embarked`, `Pclass`).
# TODO: Visualize categorical data using bar plots or count plots.
df['Pclass'].value_counts().plot(kind='pie',x=df.Pclass,autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# 4. Explore Numerical Data
# TODO: Use histograms or box plots to understand the distribution of numerical columns (e.g., `Age`, `Fare`).
# TODO: Check for outliers in numerical columns using box plots or z-scores.
# TODO: Analyze correlations between numerical columns using `.corr()` and visualize with a heatmap.
z_score_of_age = (df['Age'] - df['Age'].mean())/df['Age'].std()
z_score_of_age.plot(kind='hist',bins=30,edgecolor='black',title='Z-Score Distribution of Titanic Data')
# Out:
# <Axes: title={'center': 'Z-Score Distribution of Titanic Data'}, ylabel='Frequency'>

# %%
# 5. Analyze Relationships
# TODO: Explore relationships between variables (e.g., survival rate by `Sex`, `Pclass`, or `Age`).
# TODO: Use groupby operations to aggregate data (e.g., average `Fare` by `Pclass` or survival rate by `Embarked`).
# TODO: Visualize relationships using scatter plots, pair plots, or pivot tables.
# df.groupby('Fare')['Pclass'].agg(['mean','max','min','count'])
df.groupby('Embarked')['Survived'].agg('mean').plot(kind='pie',autopct='%1.1f%%',title='Average mark survival rate by embarked')
# Out:
# <Axes: title={'center': 'Average mark survival rate by embarked'}, ylabel='Survived'>

# %%
# 6. Feature Engineering
# TODO: Create new features if needed (e.g., extract titles from `Name`, create age groups, or categorize `Fare` into bins).
# TODO: Encode categorical variables (e.g., `Sex`, `Embarked`) using one-hot encoding or label encoding.

# %%
# 7. Analyze Target Variable
# TODO: If the dataset has a target variable (e.g., `Survived`), analyze its distribution (e.g., percentage of survivors vs. non-survivors).
# TODO: Explore how other features influence the target variable (e.g., survival rate by `Sex` or `Pclass`).

# %%
# 8. Visualizations
# TODO: Create visualizations to summarize findings (e.g., survival rate by gender, distribution of `Age`, etc.).
# TODO: Use libraries like `matplotlib` or `seaborn` for visualizations.

# %%
# 9. Draw Insights
# TODO: Summarize key findings from the analysis (e.g., which factors contributed most to survival?).
# TODO: Identify patterns or trends in the data.

# %%
# 10. Save Processed Data (Optional)
# TODO: Save the cleaned/processed dataset to a new CSV file using `.to_csv()` if needed for further analysis or modeling.
# df.isnull().sum()
df.to_csv('titanic_data_cleaned.csv')
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
